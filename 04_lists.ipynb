# %%
### lists ###

# Definision

my_list = list()
my_onther_list = []

print(len(my_list))

my_list = [35,24,62,52,30,30,17]

print(my_list)
print(len(my_list))

my_onther_list = [35,1.77,"nombre,apellido"]

print(type(my_list))
print(type(my_onter_list))

#Acceso a elementos y busqueda

print(my_onther_list[0])
print(my_onther_list[1])
print(my_onther_list[-1])
print(my_other_list[-4])
print(my_list.count(30))

# print(my_onther_list[4]) # IndexError
#print(my_onther_list[-5]) IndexError

print(my_onther_list.index("nombre"))

age, helght,name,surname = my_onther_list
print(ngame)

name,belght,age,surname = my_onther_list[2], my_onther_list[1],my_onther_list[0],my_onther_list[3]

# Concatenisacion

print(my_list + my_onther_list)
#print(my_list-my_onther_list)

# concatenasion,insercion,actualisasion y eliminacion

my_onther_list.append("CECYTEM")
print(my_onther_list)
