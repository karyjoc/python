# %%
### Variables ##

my_string_variables ="My String variable"
print(my_string_variable)

my_int_variable=5
print(my_int_variable)

my_int_to_str_variable=str(my_int_variable)
print(my_int_to_str_variable)
print(type(mu_int_to_str_variable))

mu_bool_variable=False
print(my_bool_variable)


#concarenasionde variables en un print
print(my_string_variable,my_int_to_str_variable)
print("Este es el valor de")

#Algunas funsiones de sistema
print(len(my_string_variable))# lon sirve para contar contra los caracteres de la variable

#Variables en una sola linea.¡cuidado con abusar de esta sintaxis!
name,
# Out:
#   File "<ipython-input-1-a75c0ff51e5d>", line 19
#     print(
#           ^
# SyntaxError: incomplete input
