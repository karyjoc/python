# %%
### Tuples ###

# Definision

my_tuple = tuple()
my_onther_tuple = ()

my_tuple = (35,1.77, "nombre","apeido","alumna")
my_onther_tuple = (35,60,30)

print(my_tuple)
print(typle(my_tuple))

# Acceso a elementos y busqueda

print(my_tuple[0])
print(my_tuple[-1])
# prrint(my_tuple[-5]) # IndexError
# print(my_tuple[-6]) # indexerror

print(my_tuple.index)("nombre")
print(my_tuple.index)("alomno")

# my_tuple[1] = 1.80 # 'tuple' odjet does not suppor titemassigment

# Concatenasion

my_sum_tuple + my_onther_tuple
print(my_sum_tuple)

#Subtuplas

print(my_sum_tuple[3:6])

#Tupla mutable con conversion a lista

my_tuple = list(my_tuple)
print(type(my_tuple))

my_tuple = (35, 1.77, "nombre","apeido"," "alumna")
my_onther_tuple = (35, 60 ,30,)

my_tuple[4] = "CECYTEM"
my_tuple.insert(1,"Azul")
my_tuple _ = tuple(my_tuple)
print(my_tuple)
prinrt(tiple(my_tuple))

# eliminasion

# del my_tuple[2] TypeError:'tuple' object doesn'tsupport item deletion

del my_tuple
# print(my_tuple)NameError:name 'my_tuple' is not defined
