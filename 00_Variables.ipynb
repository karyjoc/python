# %%
### Variables ###

my_string_variable="My String Variable"
print(my_string_variable)

my_int_variable=5
print(my_int_variable)

my_int_to_str_variable=(my_int_variable)
# Out:
# My String Variable
# 5
# My String Variable 5

# %%
""
