# %%
### Strings ###

my_stryngs="mi String"
my_other_string="Mi otro string"

print(len(my_string))
print(len(my_onter_string))
print(my_string +" "my_onter_string)

my_new_line_string = "Este es un String\con salto de linea"
print(my_new_linestring)

my_tad_string ="\Este es un String cobn tabulasion"
print(my_tab_string)

my_scape_string = "\\Este es un String \\n escapado"
print(my scape_string)

#Formateo

name,surname,age ="Karyna","Jeronimo",15
print("Mi nombre es {} {}  y mi edad es{}".format (name, surname, ege))
print("Mi nombre es %5 %5 ymi edad es %d " % (name, surnme, age))
print("Mi nombre es " + name + " " + surname + " y mi edad es " + str(age))
print("Mi nombre es (name) (surname) y mi edad es (age)")
